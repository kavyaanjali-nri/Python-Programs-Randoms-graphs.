# %%
import random

# %%
a1=[]
a2=[]
a3=[]
a4=[]
a5=[]

# %%
for _ in range (1000):  
   a1.append (random.randint(0,100))  
   a2.append (random.randint(50,70)) 
   a3.append (random.randint(10,20))
   a4.append (random.randint(5,10))
   a5.append (random.randint(20,80))

# %%
df = {
    'grade' : a1,
    'weight' : a2,
    'friends' : a3,
    'cousins' : a4,
    'projects' : a5
}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df1)

# %%
df1.describe()
# Out:
#              grade       weight      friends     cousins     projects
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.000000
# mean     49.926000    60.223000    14.939000     7.53300    49.523000
# std      28.938451     6.096921     3.205551     1.68575    17.651262
# min       0.000000    50.000000    10.000000     5.00000    20.000000
# 25%      26.000000    55.000000    12.000000     6.00000    34.000000
# 50%      50.000000    60.000000    15.000000     7.50000    50.000000
# 75%      75.000000    66.000000    18.000000     9.00000    65.000000
# max     100.000000    70.000000    20.000000    10.00000    80.000000

# %%
df1['grade'].count
# Out:
# <bound method Series.count of 0      88
# 1       7
# 2      48
# 3      55
# 4      86
#        ..
# 995    41
# 996    66
# 997    98
# 998    33
# 999    81
# Name: grade, Length: 1000, dtype: int64>

# %%
friend15=df1['friends']>75

# %%
friend18=df1['friends']>18

# %%
df1[friend18]
# Out:
#      grade  weight  friends  cousins  projects
# 1        7      65       19        6        32
# 6       39      65       20        9        52
# 20      74      66       20        9        39
# 22      22      67       20        9        31
# 28      19      70       19        5        54
# ..     ...     ...      ...      ...       ...
# 967      9      70       19       10        25
# 969     45      64       20        8        34
# 992     58      62       20       10        24
# 995     41      63       20        6        20
# 997     98      68       20        8        34
#
# [187 rows x 5 columns]

# %%
grade98=df1['grade']>98

# %%
df1[grade98]
# Out:
#      grade  weight  friends  cousins  projects
# 49     100      54       16        5        65
# 84      99      68       10        7        32
# 242    100      56       15        8        64
# 263    100      64       20        6        46
# 321    100      63       18        8        35
# 345     99      60       20        7        71
# 376    100      58       15        5        56
# 456    100      55       17        9        43
# 517    100      59       12       10        34
# 559     99      60       18        8        50
# 622     99      60       19        6        26
# 721    100      69       10        8        21
# 725     99      66       11       10        63
# 730    100      51       14        9        52
# 846    100      56       11       10        33
# 913     99      60       18        7        27
# 942    100      56       17        6        48

# %%
df1[friend15 & grade50]['friends']
# Out:
# Series([], Name: friends, dtype: int64)

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.0 is available.
# You should consider upgrading via the 'C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
df1[friend18 & grade50].plot()
# Out:
# <Axes: >

# %%
df1[friend18 & grade50].plot(x ='grade',y='projects',kind='bar')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend18 & grade50].plot(x = ['grade','friends'] , y =['projects','weight'],kind='scatter',tittle='sample graph')
plt. xlabel('X Axis')
plt. ylabel('Y Axis')
plt.legend('Test Data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 df1[friend18 & grade50].plot(x = ['grade','friends'] , y =['projects','weight'],kind='scatter',tittle='sample graph')
#       2 plt. xlabel('X Axis')
#       3 plt. ylabel('Y Axis')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     973 if kind in self._dataframe_kinds:
#     974     if isinstance(data, ABCDataFrame):
# --> 975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
#     977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ...
